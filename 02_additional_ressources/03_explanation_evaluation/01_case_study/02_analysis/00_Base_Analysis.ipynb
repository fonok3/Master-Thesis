# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %matplotlib inline

# Import data
df = pd.read_csv("data/all_data_3.csv");

# Set user groups from enabled features

# Abbreviations:
# - BG: User got no explanations (base group).

df.loc[(df['GpsQuality'] == False) & (df['TrafficVolume'] == False) & (df['RouteExplanation'] == False) & (df['UserCount'] == False), 'task'] = "BG"
#df.loc[(df['GpsQuality'] == False) & (df['TrafficVolume'] == False) & (df['RouteExplanation'] == True) & (df['UserCount'] == True), 'task'] = "AE"
#df.loc[(df['GpsQuality'] == True) & (df['TrafficVolume'] == True) & (df['RouteExplanation'] == False) & (df['UserCount'] == False), 'task'] = "NE"
#df.loc[(df['GpsQuality'] == True) & (df['TrafficVolume'] == True) & (df['RouteExplanation'] == True) & (df['UserCount'] == True), 'task'] = "GE"

df = df[df['task'].notna()]

df = df[df['DistanceTraveledInMeters'] > 5000]
df.loc[(df['LowAccuracyCounter'].isna()), 'LowAccuracyCounter'] = 0
df.loc[(df['DistanceTraveledInMeters'].isna()), 'DistanceTraveledInMeters'] = 0
df.loc[(df['NumberOfTimesSeenUserCountExplanationShort'].isna()), 'NumberOfTimesSeenUserCountExplanationShort'] = 0
df.loc[(df['NumberOfTimesSeenUserCountExplanationLong'].isna()), 'NumberOfTimesSeenUserCountExplanationLong'] = 0
df.loc[(df['NumberOfTimesSeenCollaborativeRoutingExplanation'].isna()), 'NumberOfTimesSeenCollaborativeRoutingExplanation'] = 0
df.loc[(df['NumberOfUnnormalRoutes'].isna()), 'NumberOfUnnormalRoutes'] = 0
df["LowAccuracyPerKilometer"] = df["LowAccuracyCounter"] / (df["DistanceTraveledInMeters"] / 1000)
df["DrivingTimeDif"] = (df["ActualDrivingTime"] - df["EstimatedDrivingTime"])
df.loc[(np.abs(df['DrivingTimeDif']) < 2000), 'DrivingTimeDif'] = 0
df["DrivingTimeRelativDif"] = df["DrivingTimeDif"] / df["EstimatedDrivingTime"]

df.loc[(np.abs(df['DrivingTimeDif']) > 0.1), 'BadETA'] = True
df.loc[(np.abs(df['DrivingTimeDif']) <= 0.1), 'BadETA'] = False

df.loc[(np.abs(df['LowAccuracyPerKilometer']) > 0.2), 'BadAccuracy'] = True
df.loc[(np.abs(df['LowAccuracyPerKilometer']) <= 0.2), 'BadAccuracy'] = False

df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df[df['DrivingTimeDif'].notna()]

# Remove fields with redundant information
df = df.drop(columns=['GpsQuality', 'TrafficVolume', 'RouteExplanation', 'UserCount'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4807 entries, 33 to 41528
# Data columns (total 20 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   DeviceId                                          4807 non-null   object
#  1   numberOfRoutes                                    4807 non-null   int64
#  2   InitialTrafficVolume                              4807 non-null   object
#  3   DistanceTraveledInMeters                          4807 non-null   int64
#  4   OffRoutePerTenKilometers                          4807 non-null   float64
#  5   LowAccuracyCounter                                4807 non-null   int64
#  6   Rating                                            133 non-null    float64
#  7   NumberOfTimesSeenUserCountExplanationShort        4807 non-null   float64
#  8   NumberOfTimesSeenUserCountExplanationLong         4807 non-null   float64
#  9   NumberOfTimesSeenCollaborativeRoutingExplanation  4807 non-null   float64
#  10  ActualDrivingTime                                 4807 non-null   int64
#  11  EstimatedDrivingTime                              4807 non-null   int64
#  12  MaxLowAccuracy                                    4807 non-null   int64
#  13  NumberOfUnnormalRoutes                            4807 non-null   float64
#  14  task                                              4807 non-null   object
#  15  LowAccuracyPerKilometer                           4807 non-null   float64
#  16  DrivingTimeDif                                    4807 non-null   int64
#  17  DrivingTimeRelativDif                             4806 non-null   float64
#  18  BadETA                                            4807 non-null   bool
#  19  BadAccuracy                                       4807 non-null   bool
# dtypes: bool(2), float64(8), int64(7), object(3)
# memory usage: 722.9+ KB

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a64d9_row0_col0, #T_a64d9_row1_col1, #T_a64d9_row2_col2, #T_a64d9_row3_col3, #T_a64d9_row4_col4, #T_a64d9_row5_col5, #T_a64d9_row6_col6, #T_a64d9_row7_col7, #T_a64d9_row8_col8, #T_a64d9_row9_col9, #T_a64d9_row10_col10, #T_a64d9_row11_col11, #T_a64d9_row12_col12, #T_a64d9_row13_col13, #T_a64d9_row14_col14, #T_a64d9_row15_col15, #T_a64d9_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a64d9_row0_col1, #T_a64d9_row0_col3, #T_a64d9_row0_col8, #T_a64d9_row0_col15, #T_a64d9_row1_col11, #T_a64d9_row1_col12, #T_a64d9_row1_col16, #T_a64d9_row2_col4, #T_a64d9_row3_col5, #T_a64d9_row4_col2, #T_a64d9_row4_col10, #T_a64d9_row9_col0, #T_a64d9_row9_col11, #T_a64d9_row9_col13, #T_a64d9_row9_col14, #T_a64d9_row9_col16, #T_a64d9_row13_col9, #T_a64d9_row15_col6, #T_a64d9_row15_col7, #T_a64d9_row15_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a64d9_row0_col2, #T_a64d9_row4_col9, #T_a64d9_row10_col9 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_a64d9_row0_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_a64d9_row0_col5, #T_a64d9_row2_col1, #T_a64d9_row4_col8, #T_a64d9_row5_col8, #T_a64d9_row12_col11 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_a64d9_row0_col6, #T_a64d9_row0_col12, #T_a64d9_row0_col16, #T_a64d9_row5_col3, #T_a64d9_row7_col16 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_a64d9_row0_col7, #T_a64d9_row5_col15, #T_a64d9_row10_col7, #T_a64d9_row12_col1, #T_a64d9_row13_col6, #T_a64d9_row13_col11 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a64d9_row0_col9, #T_a64d9_row6_col11, #T_a64d9_row11_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a64d9_row0_col10, #T_a64d9_row8_col10 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_a64d9_row0_col11 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_a64d9_row0_col13 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a64d9_row0_col14, #T_a64d9_row2_col0, #T_a64d9_row7_col1, #T_a64d9_row12_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_a64d9_row1_col0, #T_a64d9_row3_col11, #T_a64d9_row6_col8, #T_a64d9_row12_col15 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a64d9_row1_col2, #T_a64d9_row2_col13 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_a64d9_row1_col3, #T_a64d9_row11_col9 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_a64d9_row1_col4, #T_a64d9_row6_col7, #T_a64d9_row7_col6, #T_a64d9_row9_col4, #T_a64d9_row10_col2, #T_a64d9_row14_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_a64d9_row1_col5, #T_a64d9_row1_col6, #T_a64d9_row2_col6, #T_a64d9_row3_col6, #T_a64d9_row3_col7, #T_a64d9_row8_col5, #T_a64d9_row8_col6, #T_a64d9_row9_col5, #T_a64d9_row9_col7, #T_a64d9_row9_col12, #T_a64d9_row16_col5, #T_a64d9_row16_col7, #T_a64d9_row16_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_a64d9_row1_col7, #T_a64d9_row2_col11, #T_a64d9_row8_col16, #T_a64d9_row11_col8, #T_a64d9_row13_col7, #T_a64d9_row16_col15 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a64d9_row1_col8, #T_a64d9_row8_col9 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_a64d9_row1_col9 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_a64d9_row1_col10 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_a64d9_row1_col13 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_a64d9_row1_col14, #T_a64d9_row10_col11, #T_a64d9_row14_col7, #T_a64d9_row16_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_a64d9_row1_col15, #T_a64d9_row4_col13, #T_a64d9_row16_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_a64d9_row2_col3, #T_a64d9_row5_col10 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_a64d9_row2_col5, #T_a64d9_row2_col7, #T_a64d9_row8_col11, #T_a64d9_row9_col6, #T_a64d9_row10_col5, #T_a64d9_row12_col5, #T_a64d9_row15_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_a64d9_row2_col8, #T_a64d9_row5_col14, #T_a64d9_row10_col14, #T_a64d9_row11_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_a64d9_row2_col9, #T_a64d9_row5_col13, #T_a64d9_row6_col13, #T_a64d9_row11_col13, #T_a64d9_row15_col1, #T_a64d9_row15_col14 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_a64d9_row2_col10, #T_a64d9_row14_col9 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_a64d9_row2_col12 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_a64d9_row2_col14, #T_a64d9_row7_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_a64d9_row2_col15, #T_a64d9_row5_col11, #T_a64d9_row15_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_a64d9_row2_col16 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_a64d9_row3_col0, #T_a64d9_row4_col14, #T_a64d9_row6_col12, #T_a64d9_row11_col14, #T_a64d9_row12_col14, #T_a64d9_row13_col16, #T_a64d9_row14_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a64d9_row3_col1, #T_a64d9_row12_col13 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_a64d9_row3_col2, #T_a64d9_row8_col15 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_a64d9_row3_col4, #T_a64d9_row3_col9 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_a64d9_row3_col8, #T_a64d9_row10_col4, #T_a64d9_row11_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_a64d9_row3_col10 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_a64d9_row3_col12 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_a64d9_row3_col13, #T_a64d9_row10_col13 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_a64d9_row3_col14, #T_a64d9_row4_col15, #T_a64d9_row6_col14, #T_a64d9_row7_col12, #T_a64d9_row14_col12, #T_a64d9_row15_col12, #T_a64d9_row16_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_a64d9_row3_col15 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_a64d9_row3_col16 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_a64d9_row4_col0, #T_a64d9_row4_col16, #T_a64d9_row5_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_a64d9_row4_col1, #T_a64d9_row6_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_a64d9_row4_col3, #T_a64d9_row7_col11, #T_a64d9_row10_col8, #T_a64d9_row11_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_a64d9_row4_col5, #T_a64d9_row4_col6, #T_a64d9_row4_col7, #T_a64d9_row4_col11, #T_a64d9_row5_col4, #T_a64d9_row6_col4, #T_a64d9_row7_col4, #T_a64d9_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a64d9_row4_col12, #T_a64d9_row13_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a64d9_row5_col1, #T_a64d9_row13_col1, #T_a64d9_row15_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_a64d9_row5_col2, #T_a64d9_row6_col2, #T_a64d9_row7_col2, #T_a64d9_row8_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_a64d9_row5_col6 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_a64d9_row5_col7, #T_a64d9_row15_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_a64d9_row5_col9, #T_a64d9_row7_col9 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_a64d9_row5_col12, #T_a64d9_row14_col3, #T_a64d9_row14_col16 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_a64d9_row5_col16, #T_a64d9_row6_col3, #T_a64d9_row6_col16, #T_a64d9_row7_col3, #T_a64d9_row11_col16, #T_a64d9_row15_col16 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a64d9_row6_col1, #T_a64d9_row8_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_a64d9_row6_col5 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_a64d9_row6_col9 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_a64d9_row6_col10, #T_a64d9_row10_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_a64d9_row6_col15, #T_a64d9_row7_col15, #T_a64d9_row10_col6, #T_a64d9_row11_col15, #T_a64d9_row12_col6, #T_a64d9_row12_col8, #T_a64d9_row16_col6, #T_a64d9_row16_col11 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_a64d9_row7_col5, #T_a64d9_row10_col12, #T_a64d9_row12_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_a64d9_row7_col8, #T_a64d9_row8_col12 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a64d9_row7_col10, #T_a64d9_row14_col10 {
#   background-color: #7093f3;
#   col

# %%
chartColors=["#00509B", "#C8D317", "#999999", "#8FA6CA", "#EE6429", "#E4AF8E"]

# %%
g = df.groupby(['DeviceId', 'task']).mean()
grouped_data_raw = g.reset_index()

grouped_data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1210 entries, 0 to 1209
# Data columns (total 19 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   DeviceId                                          1210 non-null   object
#  1   task                                              1210 non-null   object
#  2   numberOfRoutes                                    1210 non-null   float64
#  3   DistanceTraveledInMeters                          1210 non-null   float64
#  4   OffRoutePerTenKilometers                          1210 non-null   float64
#  5   LowAccuracyCounter                                1210 non-null   float64
#  6   Rating                                            44 non-null     float64
#  7   NumberOfTimesSeenUserCountExplanationShort        1210 non-null   float64
#  8   NumberOfTimesSeenUserCountExplanationLong         1210 non-null   float64
#  9   NumberOfTimesSeenCollaborativeRoutingExplanation  1210 non-null   float64
#  10  ActualDrivingTime                                 1210 non-null   float64
#  11  EstimatedDrivingTime                              1210 non-null   float64
#  12  MaxLowAccuracy                                    1210 non-null   float64
#  13  NumberOfUnnormalRoutes                            1210 non-null   float64
#  14  LowAccuracyPerKilometer                           1210 non-null   float64
#  15  DrivingTimeDif                                    1210 non-null   float64
#  16  DrivingTimeRelativDif                             1210 non-null   float64
#  17  BadETA                                            1210 non-null   float64
#  18  BadAccuracy                                       1210 non-null   float64
# dtypes: float64(17), object(2)
# memory usage: 179.7+ KB

# %%
corr = grouped_data_raw.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b893a_row0_col0, #T_b893a_row1_col1, #T_b893a_row2_col2, #T_b893a_row3_col3, #T_b893a_row4_col4, #T_b893a_row5_col5, #T_b893a_row6_col6, #T_b893a_row7_col7, #T_b893a_row8_col8, #T_b893a_row9_col9, #T_b893a_row10_col10, #T_b893a_row11_col11, #T_b893a_row12_col12, #T_b893a_row13_col13, #T_b893a_row14_col14, #T_b893a_row15_col15, #T_b893a_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col1, #T_b893a_row1_col0, #T_b893a_row2_col11, #T_b893a_row3_col6, #T_b893a_row8_col7, #T_b893a_row14_col11 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_b893a_row0_col3, #T_b893a_row1_col11, #T_b893a_row2_col5, #T_b893a_row6_col8, #T_b893a_row7_col3, #T_b893a_row8_col5, #T_b893a_row8_col11, #T_b893a_row9_col11, #T_b893a_row12_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col4, #T_b893a_row1_col15, #T_b893a_row9_col4, #T_b893a_row15_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_b893a_row0_col5, #T_b893a_row6_col15, #T_b893a_row7_col14, #T_b893a_row11_col15, #T_b893a_row16_col15 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col7, #T_b893a_row11_col10 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col8, #T_b893a_row2_col6, #T_b893a_row2_col7, #T_b893a_row3_col7, #T_b893a_row11_col8, #T_b893a_row15_col0, #T_b893a_row16_col5, #T_b893a_row16_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_b893a_row0_col10, #T_b893a_row15_col14 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_b893a_row0_col11, #T_b893a_row10_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col12, #T_b893a_row13_col16 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col13 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_b893a_row0_col14, #T_b893a_row9_col10 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col15, #T_b893a_row5_col11, #T_b893a_row5_col14 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_b893a_row0_col16, #T_b893a_row3_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_b893a_row1_col2, #T_b893a_row13_col4 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_b893a_row1_col3, #T_b893a_row4_col14 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_b893a_row1_col4, #T_b893a_row2_col12 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_b893a_row1_col5, #T_b893a_row9_col6, #T_b893a_row12_col8 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b893a_row1_col6, #T_b893a_row8_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_b893a_row1_col7, #T_b893a_row12_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_b893a_row1_col8, #T_b893a_row12_col3 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_b893a_row1_col9 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_b893a_row1_col10, #T_b893a_row2_col14 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_b893a_row1_col12, #T_b893a_row1_col16, #T_b893a_row2_col1, #T_b893a_row2_col4, #T_b893a_row3_col5, #T_b893a_row4_col2, #T_b893a_row4_col10, #T_b893a_row5_col3, #T_b893a_row9_col0, #T_b893a_row9_col5, #T_b893a_row9_col7, #T_b893a_row9_col13, #T_b893a_row9_col14, #T_b893a_row9_col16, #T_b893a_row12_col1, #T_b893a_row13_col9, #T_b893a_row13_col15, #T_b893a_row15_col6, #T_b893a_row15_col7, #T_b893a_row15_col11, #T_b893a_row16_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b893a_row1_col13, #T_b893a_row6_col9, #T_b893a_row7_col9, #T_b893a_row12_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_b893a_row1_col14, #T_b893a_row6_col12, #T_b893a_row7_col1, #T_b893a_row15_col12 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_b893a_row2_col0, #T_b893a_row11_col1, #T_b893a_row11_col3, #T_b893a_row12_col11, #T_b893a_row14_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b893a_row2_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_b893a_row2_col8, #T_b893a_row6_col16, #T_b893a_row7_col16, #T_b893a_row8_col12, #T_b893a_row13_col5, #T_b893a_row13_col6, #T_b893a_row14_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_b893a_row2_col9 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_b893a_row2_col10, #T_b893a_row7_col15 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b893a_row2_col13, #T_b893a_row14_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_b893a_row2_col15 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_b893a_row2_col16 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b893a_row3_col1, #T_b893a_row15_col13 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_b893a_row3_col2, #T_b893a_row13_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_b893a_row3_col4, #T_b893a_row4_col13, #T_b893a_row8_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_b893a_row3_col8, #T_b893a_row11_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b893a_row3_col9, #T_b893a_row16_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_b893a_row3_col10 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_b893a_row3_col11, #T_b893a_row4_col8, #T_b893a_row5_col12, #T_b893a_row14_col16 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b893a_row3_col12 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_b893a_row3_col13, #T_b893a_row5_col7, #T_b893a_row7_col13, #T_b893a_row8_col14, #T_b893a_row12_col13, #T_b893a_row16_col13 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_b893a_row3_col14, #T_b893a_row4_col16, #T_b893a_row12_col14 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b893a_row3_col15, #T_b893a_row15_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b893a_row3_col16 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_b893a_row4_col0, #T_b893a_row4_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_b893a_row4_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_b893a_row4_col3, #T_b893a_row5_col16, #T_b893a_row11_col16, #T_b893a_row13_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_b893a_row4_col5, #T_b893a_row4_col6, #T_b893a_row4_col7, #T_b893a_row4_col11, #T_b893a_row5_col4, #T_b893a_row6_col4, #T_b893a_row7_col4, #T_b893a_row11_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_b893a_row4_col9, #T_b893a_row10_col16 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_b893a_row4_col15, #T_b893a_row12_col9, #T_b893a_row15_col8, #T_b893a_row16_col9 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_b893a_row5_col0, #T_b893a_row6_col11, #T_b893a_row8_col3, #T_b893a_row11_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b893a_row5_col1, #T_b893a_row8_col0, #T_b893a_row10_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b893a_row5_col2, #T_b893a_row6_col2, #T_b893a_row7_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_b893a_row5_col6 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_b893a_row5_col8, #T_b893a_row16_col1, #T_b893a_row16_col6, #T_b893a_row16_col11 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_b893a_row5_col9, #T_b893a_row11_col9 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_b893a_row5_col10, #T_b893a_row10_col11, #T_b893a_row11_col14 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_b893a_row5_col13, #T_b893a_row7_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_b893a_row5_col15, #T_b893a_row12_col15 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_b893a_row6_col0, #T_b893a_row10_col15 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b893a_row6_col1, #T_b893a_row13_col1, #T_b893a_row13_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_b893a_row6_col3, #T_b893a_row8_col16, #T_b893a_row9_col12, #T_b893a_row15_col5, #T_b893a_row15_col16 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_b893a_row6_col5 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_b893a_row6_c

# %%
# Filter for unusable data
filtered_data = df

filtered_data = filtered_data[filtered_data['DistanceTraveledInMeters']>5000]

filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4807 entries, 33 to 41528
# Data columns (total 20 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   DeviceId                                          4807 non-null   object
#  1   numberOfRoutes                                    4807 non-null   int64
#  2   InitialTrafficVolume                              4807 non-null   object
#  3   DistanceTraveledInMeters                          4807 non-null   int64
#  4   OffRoutePerTenKilometers                          4807 non-null   float64
#  5   LowAccuracyCounter                                4807 non-null   int64
#  6   Rating                                            133 non-null    float64
#  7   NumberOfTimesSeenUserCountExplanationShort        4807 non-null   float64
#  8   NumberOfTimesSeenUserCountExplanationLong         4807 non-null   float64
#  9   NumberOfTimesSeenCollaborativeRoutingExplanation  4807 non-null   float64
#  10  ActualDrivingTime                                 4807 non-null   int64
#  11  EstimatedDrivingTime                              4807 non-null   int64
#  12  MaxLowAccuracy                                    4807 non-null   int64
#  13  NumberOfUnnormalRoutes                            4807 non-null   float64
#  14  task                                              4807 non-null   object
#  15  LowAccuracyPerKilometer                           4807 non-null   float64
#  16  DrivingTimeDif                                    4807 non-null   int64
#  17  DrivingTimeRelativDif                             4806 non-null   float64
#  18  BadETA                                            4807 non-null   bool
#  19  BadAccuracy                                       4807 non-null   bool
# dtypes: bool(2), float64(8), int64(7), object(3)
# memory usage: 722.9+ KB

# %%
g = filtered_data.groupby(['DeviceId', 'task']).mean()
grouped_data_filtered = g.reset_index()

grouped_data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1210 entries, 0 to 1209
# Data columns (total 19 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   DeviceId                                          1210 non-null   object
#  1   task                                              1210 non-null   object
#  2   numberOfRoutes                                    1210 non-null   float64
#  3   DistanceTraveledInMeters                          1210 non-null   float64
#  4   OffRoutePerTenKilometers                          1210 non-null   float64
#  5   LowAccuracyCounter                                1210 non-null   float64
#  6   Rating                                            44 non-null     float64
#  7   NumberOfTimesSeenUserCountExplanationShort        1210 non-null   float64
#  8   NumberOfTimesSeenUserCountExplanationLong         1210 non-null   float64
#  9   NumberOfTimesSeenCollaborativeRoutingExplanation  1210 non-null   float64
#  10  ActualDrivingTime                                 1210 non-null   float64
#  11  EstimatedDrivingTime                              1210 non-null   float64
#  12  MaxLowAccuracy                                    1210 non-null   float64
#  13  NumberOfUnnormalRoutes                            1210 non-null   float64
#  14  LowAccuracyPerKilometer                           1210 non-null   float64
#  15  DrivingTimeDif                                    1210 non-null   float64
#  16  DrivingTimeRelativDif                             1210 non-null   float64
#  17  BadETA                                            1210 non-null   float64
#  18  BadAccuracy                                       1210 non-null   float64
# dtypes: float64(17), object(2)
# memory usage: 179.7+ KB

# %%
# Only use data relevant for offroute analysis

or_data = filtered_data

or_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4807 entries, 33 to 41528
# Data columns (total 20 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   DeviceId                                          4807 non-null   object
#  1   numberOfRoutes                                    4807 non-null   int64
#  2   InitialTrafficVolume                              4807 non-null   object
#  3   DistanceTraveledInMeters                          4807 non-null   int64
#  4   OffRoutePerTenKilometers                          4807 non-null   float64
#  5   LowAccuracyCounter                                4807 non-null   int64
#  6   Rating                                            133 non-null    float64
#  7   NumberOfTimesSeenUserCountExplanationShort        4807 non-null   float64
#  8   NumberOfTimesSeenUserCountExplanationLong         4807 non-null   float64
#  9   NumberOfTimesSeenCollaborativeRoutingExplanation  4807 non-null   float64
#  10  ActualDrivingTime                                 4807 non-null   int64
#  11  EstimatedDrivingTime                              4807 non-null   int64
#  12  MaxLowAccuracy                                    4807 non-null   int64
#  13  NumberOfUnnormalRoutes                            4807 non-null   float64
#  14  task                                              4807 non-null   object
#  15  LowAccuracyPerKilometer                           4807 non-null   float64
#  16  DrivingTimeDif                                    4807 non-null   int64
#  17  DrivingTimeRelativDif                             4806 non-null   float64
#  18  BadETA                                            4807 non-null   bool
#  19  BadAccuracy                                       4807 non-null   bool
# dtypes: bool(2), float64(8), int64(7), object(3)
# memory usage: 722.9+ KB

# %%
# Remove outliers
#
# > An outlier of a dataset is defined as a value that is more than 3 standard deviations from the mean.
# > Removing outliers from a pandas.DataFrame removes any rows in the DataFrame which contain an outlier.
# > Outlier calculations are performed separately for each column.

or_data = or_data[np.abs(or_data.OffRoutePerTenKilometers-or_data.OffRoutePerTenKilometers.mean())<=(3*or_data.OffRoutePerTenKilometers.std())]

or_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4741 entries, 33 to 41528
# Data columns (total 20 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   DeviceId                                          4741 non-null   object
#  1   numberOfRoutes                                    4741 non-null   int64
#  2   InitialTrafficVolume                              4741 non-null   object
#  3   DistanceTraveledInMeters                          4741 non-null   int64
#  4   OffRoutePerTenKilometers                          4741 non-null   float64
#  5   LowAccuracyCounter                                4741 non-null   int64
#  6   Rating                                            133 non-null    float64
#  7   NumberOfTimesSeenUserCountExplanationShort        4741 non-null   float64
#  8   NumberOfTimesSeenUserCountExplanationLong         4741 non-null   float64
#  9   NumberOfTimesSeenCollaborativeRoutingExplanation  4741 non-null   float64
#  10  ActualDrivingTime                                 4741 non-null   int64
#  11  EstimatedDrivingTime                              4741 non-null   int64
#  12  MaxLowAccuracy                                    4741 non-null   int64
#  13  NumberOfUnnormalRoutes                            4741 non-null   float64
#  14  task                                              4741 non-null   object
#  15  LowAccuracyPerKilometer                           4741 non-null   float64
#  16  DrivingTimeDif                                    4741 non-null   int64
#  17  DrivingTimeRelativDif                             4740 non-null   float64
#  18  BadETA                                            4741 non-null   bool
#  19  BadAccuracy                                       4741 non-null   bool
# dtypes: bool(2), float64(8), int64(7), object(3)
# memory usage: 713.0+ KB

# %%
sns.set()
sns.boxplot(data=df, x=or_data.task, y=or_data.OffRoutePerTenKilometers)
plt.show()

# %% [markdown]
# p < 0.05 -> we can reject the 0-Hypotheses.
#
# Groups are not normally distributed thus we have to take Kruskal Wallis instead of ANONVA
#
# ### References
#
# - Glass, G.V., P.D. Peckham, and J.R. Sanders. 1972. Consequences of failure to meet assumptions underlying fixed effects analyses of variance and covariance. Rev. Educ. Res. 42: 237-288.
# - Harwell, M.R., E.N. Rubinstein, W.S. Hayes, and C.C. Olds. 1992. Summarizing Monte Carlo results in methodological research: the one- and two-factor fixed effects ANOVA cases. J. Educ. Stat. 17: 315-339.
# - Lix, L.M., J.C. Keselman, and H.J. Keselman. 1996. Consequences of assumption violations revisited: A quantitative review of alternatives to the one-way analysis of variance F test. Rev. Educ. Res. 66: 579-619.

# %%
import pingouin as pg

res = pg.kruskal(data=or_data, dv='OffRoutePerTenKilometers', between='BadAccuracy')

print(res)
# Out:
#               Source  ddof1          H         p-unc
# Kruskal  BadAccuracy      1  62.004576  3.426601e-15

# %% [markdown]
# p < 0.05 --> we can reject the 0-Hypothesis.

# %%
import scipy.stats as st
import scikit_posthocs as sp
from statsmodels.stats.anova import AnovaRM

#pairwise testing:

pc = sp.posthoc_dunn(or_data, val_col="OffRoutePerTenKilometers", group_col='BadAccuracy', p_adjust="bonferroni")


heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
sp.sign_plot(pc, **heatmap_args)
plt.show()
print(pc)

print("Mean Bad Accuracy: ", or_data[or_data.BadAccuracy == True].OffRoutePerTenKilometers.mean(), "BG: ", or_data[or_data.task == "BG"].OffRoutePerTenKilometers.median(), " STD: ", or_data[or_data.task == "BG"].OffRoutePerTenKilometers.std(),"")
print("Mean Good Accuracy: ", or_data[or_data.BadAccuracy == False].OffRoutePerTenKilometers.mean(), "AE: ", or_data[or_data.task == "AE"].OffRoutePerTenKilometers.median(), " STD: ", or_data[or_data.task == "AE"].OffRoutePerTenKilometers.std(),"")
# Out:
#               False          True
# False  1.000000e+00  3.426601e-15
# True   3.426601e-15  1.000000e+00
# Mean Bad Accuracy:  0.18595251418625192 BG:  0.0323676970383557  STD:  0.11959752518945468
# Mean Good Accuracy:  0.07210457884876675 AE:  nan  STD:  nan

# %%
pg.pairwise_tukey(data=or_data, dv='OffRoutePerTenKilometers', between='task')
# Out:
# /usr/local/lib/python3.9/site-packages/pingouin/parametric.py:979: RuntimeWarning: divide by zero encountered in double_scalars
#   msbetween = ssbetween / ddof1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1v/5kny07d149qdg39wrs1yxjsr0000gn/T/ipykernel_11285/755932957.py in <module>
# ----> 1 pg.pairwise_tukey(data=or_data, dv='OffRoutePerTenKilometers', between='task')
#
# /usr/local/lib/python3.9/site-packages/pingouin/pairwise.py in pairwise_tukey(data, dv, between, effsize)
#     697
#     698     # Pairwise combinations
# --> 699     g1, g2 = np.array(list(combinations(np.arange(ng), 2))).T
#     700     mn = gmeans[g1] - gmeans[g2]
#     701     se = np.sqrt(gvar[g1] + gvar[g2])
#
# ValueError: not enough values to unpack (expected 2, got 0)
